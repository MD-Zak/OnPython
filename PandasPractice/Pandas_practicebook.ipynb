# %%
import pandas as pd

# %%
df = pd.read_csv("red30.csv")

# %%
df.head()
# Out:
#    OrderNum  OrderType CustomerType                CustName       CustState  \
# 0   1100934  Wholesale     Business        Gusikowski Group  North Carolina
# 1   1100935     Retail   Individual       Spencer Educators        Delaware
# 2   1100936  Wholesale     Business           Schinner Inc.         Florida
# 3   1100937     Retail   Individual            Saxon Laviss        Virginia
# 4   1100938     Retail     Business  Wilderman Technologies           Texas
#
#       ProdCategory ProdNumber                   ProdName  Quantity     Price  \
# 0       Blueprints      BP102    Bsquare Robot Blueprint        10    $8.99
# 1       Drone Kits      DK204                   BYOD-300         2   $89.00
# 2  Training Videos      TV801            Aerial Security        10   $36.99
# 3       Robot Kits      RK602                  BYOR-1000         1  $189.00
# 4           eBooks      EB502  Building Your First Robot         4   $24.95
#
#   Discount OrderTotal
# 0   $1.80     $88.10
# ...

# %%
df.tail()
# Out:
#       OrderNum  OrderType CustomerType          CustName       CustState  \
# 4971   1105905  Wholesale     Business     Rau-Dickinson        Kentucky
# 4972   1105906  Wholesale     Business  Reichel and Sons        Oklahoma
# 4973   1105907  Wholesale     Business         Wolff LLC  South Carolina
# 4974   1105908     Retail     Business      McClure Inc.            Utah
# 4975   1105909     Retail   Individual    Gussi Strodder        New York
#
#      ProdCategory ProdNumber                   ProdName  Quantity     Price  \
# 4971       eBooks      EB503    Building Your Own Drone         5   $24.99
# 4972       eBooks      EB502  Building Your First Robot         5   $24.95
# 4973   Blueprints      BP104        Cat Robot Blueprint        10    $4.99
# 4974   Drone Kits      DK209                   BYOD-550        64  $179.00
# 4975   Drone Kits      DK204                   BYOD-300         1   $89.00
#
#      Discount   OrderTotal
# 4971   $5.00      $119.95
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderNum      4976 non-null   int64
#  1   OrderType     4976 non-null   object
#  2   CustomerType  4976 non-null   object
#  3   CustName      4976 non-null   object
#  4   CustState     4976 non-null   object
#  5   ProdCategory  4976 non-null   object
#  6   ProdNumber    4976 non-null   object
#  7   ProdName      4976 non-null   object
#  8   Quantity      4976 non-null   int64
#  9   Price         4976 non-null   object
#  10  Discount      4976 non-null   object
#  11  OrderTotal    4976 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 272.2+ KB

# %%
df['CustState'].value_counts()
# Out:
# California              386
# Florida                 374
# Texas                   370
# New York                304
# Virginia                187
# Georgia                 180
# Ohio                    179
# North Carolina          176
# Pennsylvania            159
# Tennessee               148
# Minnesota               143
# Arizona                 138
# District of Columbia    114
# Washington              112
# Indiana                 111
# Louisiana               109
# Alabama                 107
# Colorado                102
# Illinois                101
# Kansas                  101
# Missouri                100
# Massachusetts            87
# Kentucky                 81
# Michigan                 79
# Oklahoma                 70
# Maryland                 69
# Iowa                     62
# Utah                     60
# South Carolina           60
# Idaho                    58
# Nevada                   57
# Connecticut              55
# New Jersey               55
# ...

# %%
df.describe()
# Out:
#            OrderNum     Quantity
# count  4.976000e+03  4976.000000
# mean   1.103422e+06    11.107516
# std    1.436592e+03    20.367634
# min    1.100934e+06     1.000000
# 25%    1.102178e+06     1.000000
# 50%    1.103422e+06     5.000000
# 75%    1.104665e+06    10.000000
# max    1.105909e+06   109.000000

# %%
import matplotlib

# %%
df['Quantity'].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
df['CustState'].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///salespeople.sqlite')

# %%
salespeople_df = pd.read_sql_table('salespeople', con = engine.connect())

# index_col = 'idColumn', coerce_float = True, 
# parse_date = ['dateColumn'], columns = ['city', 'state'], chunksize = 250)

# %%
salespeople_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     51 non-null     object
#  1   last_name      51 non-null     object
#  2   email_address  51 non-null     object
#  3   city           51 non-null     object
#  4   state          51 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB

# %%
salespeople_df.head()
# Out:
#   first_name last_name             email_address        city          state
# 0       Jack    Powell   jpowell0@hplussport.com   Lynchburg       Virginia
# 1      Emily    Garcia   egarcia1@hplussport.com  Manchester  New Hampshire
# 2    Richard      Dean     rdean2@hplussport.com     Houston          Texas
# 3       Jane    Porter   jporter3@hplussport.com  Alexandria       Virginia
# 4      Robin   Vasquez  rvasquez4@hplussport.com     El Paso          Texas

# %%
salespeople_df['email_address']
# Out:
# 0        jpowell0@hplussport.com
# 1        egarcia1@hplussport.com
# 2          rdean2@hplussport.com
# 3        jporter3@hplussport.com
# 4       rvasquez4@hplussport.com
# 5        dflores5@hplussport.com
# 6      cjohnston6@hplussport.com
# 7       njohnson7@hplussport.com
# 8        kbishop8@hplussport.com
# 9       jstewart9@hplussport.com
# 10        dpricea@hplussport.com
# 11         jreidb@hplussport.com
# 12        rgomezc@hplussport.com
# 13       jgeorged@hplussport.com
# 14       jlarsone@hplussport.com
# 15         jcarrf@hplussport.com
# 16        jortizg@hplussport.com
# 17       jfowlerh@hplussport.com
# 18         bsimsi@hplussport.com
# 19       jwagnerj@hplussport.com
# 20        sevansk@hplussport.com
# 21        tmccoyl@hplussport.com
# 22         jruizm@hplussport.com
# 23          scoxn@hplussport.com
# 24      jalvarezo@hplussport.com
# 25       abutlerp@hplussport.com
# 26     lgonzalesq@hplussport.com
# 27        vmoorer@hplussport.com
# ...

# %%
salespeople_df['state'].value_counts().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
salespeople_df['city'].value_counts()
# Out:
# Houston           2
# El Paso           2
# Monticello        2
# Oklahoma City     2
# Seattle           2
# Lynchburg         1
# Tallahassee       1
# Kingsport         1
# Van Nuys          1
# Salt Lake City    1
# Anderson          1
# Montgomery        1
# Tampa             1
# Denver            1
# Memphis           1
# Visalia           1
# Norfolk           1
# Warren            1
# Canton            1
# Dallas            1
# Waterbury         1
# Birmingham        1
# Kansas City       1
# San Antonio       1
# Flint             1
# Minneapolis       1
# Raleigh           1
# New York City     1
# Alexandria        1
# Las Cruces        1
# Amarillo          1
# Roanoke           1
# Mesquite          1
# Lynn              1
# Garland           1
# Wichita           1
# Phoenix           1
# Bloomington       1
# Jacksonville      1
# Louisville        1
# Springfield       1
# San Jose          1
# Fort Myers        1
# Akron             1
# Manchester        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderNum      4976 non-null   int64
#  1   OrderType     4976 non-null   object
#  2   CustomerType  4976 non-null   object
#  3   CustName      4976 non-null   object
#  4   CustState     4976 non-null   object
#  5   ProdCategory  4976 non-null   object
#  6   ProdNumber    4976 non-null   object
#  7   ProdName      4976 non-null   object
#  8   Quantity      4976 non-null   int64
#  9   Price         4976 non-null   object
#  10  Discount      4976 non-null   object
#  11  OrderTotal    4976 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 272.2+ KB

# %%
df['Price'].describe()
# Out:
# count         4976
# unique          58
# top       $189.00
# freq           232
# Name: Price, dtype: object

# %%
df['Discount'].describe()
# Out:
# count     4976
# unique      58
# top          0
# freq      2143
# Name: Discount, dtype: object

# %%
df['ProdCategory'].value_counts()
# Out:
# eBooks             1296
# Training Videos     992
# Blueprints          912
# Drone Kits          552
# Robot Kits          480
# Drones              408
# Robots              336
# Name: ProdCategory, dtype: int64

# %%
df['ProdCategory'].value_counts().describe()
# Out:
# count       7.000000
# mean      710.857143
# std       358.855323
# min       336.000000
# 25%       444.000000
# 50%       552.000000
# 75%       952.000000
# max      1296.000000
# Name: ProdCategory, dtype: float64

# %%
1296+     992+          912+   552+      480+              408      +336
# Out:
# 4976

# %%
4976/7
# Out:
# 710.8571428571429

# %%
df['OrderType'].value_counts()
# Out:
# Wholesale    2833
# Retail       2143
# Name: OrderType, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderNum      4976 non-null   int64
#  1   OrderType     4976 non-null   object
#  2   CustomerType  4976 non-null   object
#  3   CustName      4976 non-null   object
#  4   CustState     4976 non-null   object
#  5   ProdCategory  4976 non-null   object
#  6   ProdNumber    4976 non-null   object
#  7   ProdName      4976 non-null   object
#  8   Quantity      4976 non-null   int64
#  9   Price         4976 non-null   object
#  10  Discount      4976 non-null   object
#  11  OrderTotal    4976 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 272.2+ KB

# %%
df['Quantity'].describe()
# Out:
# count    4976.000000
# mean       11.107516
# std        20.367634
# min         1.000000
# 25%         1.000000
# 50%         5.000000
# 75%        10.000000
# max       109.000000
# Name: Quantity, dtype: float64

# %%
df['Quantity'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df_sub = df[1:10]

# %%
df_sub.plot(kind = 'hexbin', y = 'OrderNum', x = 'Quantity')
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='OrderNum'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4976 entries, 0 to 4975
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderNum      4976 non-null   int64
#  1   OrderType     4976 non-null   object
#  2   CustomerType  4976 non-null   object
#  3   CustName      4976 non-null   object
#  4   CustState     4976 non-null   object
#  5   ProdCategory  4976 non-null   object
#  6   ProdNumber    4976 non-null   object
#  7   ProdName      4976 non-null   object
#  8   Quantity      4976 non-null   int64
#  9   Price         4976 non-null   object
#  10  Discount      4976 non-null   object
#  11  OrderTotal    4976 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 272.2+ KB

# %%
df['Quantity'].describe()
# Out:
# count    4976.000000
# mean       11.107516
# std        20.367634
# min         1.000000
# 25%         1.000000
# 50%         5.000000
# 75%        10.000000
# max       109.000000
# Name: Quantity, dtype: float64

# %%
list =df.value_counts('Quantity')
print(list)
# Out:
# Quantity
# 1      1880
# 10      277
# 8       266
# 6       265
# 9       244
#        ...
# 14        2
# 100       2
# 80        2
# 28        2
# 85        1
# Length: 109, dtype: int64

# %%
df.loc[df['Quantity'] == 100, 'ProdName']
# Out:
# 1367        Cat Robot Blueprint
# 3200    Ladybug Robot Blueprint
# Name: ProdName, dtype: object

# %%
print("The approximate pop of {} is {:,.2f}%".format("India", 121234918.293))
# Out:
# The approximate pop of India is 121,234,918.29%

# %%
df.dtypes
# Out:
# OrderNum         int64
# OrderType       object
# CustomerType    object
# CustName        object
# CustState       object
# ProdCategory    object
# ProdNumber      object
# ProdName        object
# Quantity         int64
# Price           object
# Discount        object
# OrderTotal      object
# dtype: object

# %%
df.shape
# Out:
# (4976, 12)

# %%
df[['Quantity', 'Price', 'ProdName']]
# Out:
#       Quantity     Price                   ProdName
# 0           10    $8.99     Bsquare Robot Blueprint
# 1            2   $89.00                    BYOD-300
# 2           10   $36.99             Aerial Security
# 3            1  $189.00                   BYOR-1000
# 4            4   $24.95   Building Your First Robot
# ...        ...       ...                        ...
# 4971         5   $24.99     Building Your Own Drone
# 4972         5   $24.95   Building Your First Robot
# 4973        10    $4.99         Cat Robot Blueprint
# 4974        64  $179.00                    BYOD-550
# 4975         1   $89.00                    BYOD-300
#
# [4976 rows x 3 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print('yolo world')
# Out:
# yolo world
